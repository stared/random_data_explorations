# %% [markdown]
# By [Piotr Migdał](http://p.migdal.pl/). Work in progress.
#
# Data sources:
#
# * [List of countries by suicide rate - Wikipedia](http://en.wikipedia.org/wiki/List_of_countries_by_suicide_rate)
# * [List of countries by population (United Nations) - Wikipedia](https://en.wikipedia.org/wiki/List_of_countries_by_population_%28United_Nations%29): 1 July 2015 and 2016

# %%
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
country <- read.csv("data/country_suicide.csv")
head(country)
# Out:
#       Country Both.sexes Male.rank Male Female.rank Female
# 1      Guyana       44.2         1 70.8           1   22.1
# 2 South Korea       28.9         5 41.7           5   18.0
# 3   Sri Lanka       28.8         3 46.4           7   12.8
# 4   Lithuania       28.2         2 51.0          29    8.4
# 5    Suriname       27.8         4 44.5          11   11.9
# 6  Mozambique       27.4         8 34.2           2   21.1

# %%
population <- read.csv("data/country_population.csv") %>%
  mutate(Pop.Growth.Percent=(Population.2016/Population.2015 - 1) * 100)
head(population)
# Out:
#         Country Continent.UN          Region.UN Population.2016 Population.2015
# 1         China         Asia       Eastern Asia      1382323332      1376048943
# 2         India         Asia      Southern Asia      1326801576      1311050527
# 3 United States     Americas   Northern America       324118787       321773631
# 4     Indonesia         Asia South-Eastern Asia       260581100       257563815
# 5        Brazil     Americas      South America       209567920       207847528
# 6      Pakistan         Asia      Southern Asia       192826502       188924874
#   Pop.Growth.Percent
# 1          0.4559714
# 2          1.2014067
# 3          0.7288217
# 4          1.1714708
# 5          0.8277183
# 6          2.0651743

# %%
length(intersect(population$Country, country$Country))
# Out:
# [1] 169

# %%
length(country$Country)
# Out:
# [1] 171

# %%
length(population$Country)
# Out:
# [1] 233

# %%
suicides <- inner_join(country, population)
head(suicides)
# Out:
# Joining by: "Country"
# Warning message in inner_join_impl(x, y, by$x, by$y):
# “joining factors with different levels, coercing to character vector”
#       Country Both.sexes Male.rank Male Female.rank Female Continent.UN
# 1      Guyana       44.2         1 70.8           1   22.1     Americas
# 2 South Korea       28.9         5 41.7           5   18.0         Asia
# 3   Sri Lanka       28.8         3 46.4           7   12.8         Asia
# 4   Lithuania       28.2         2 51.0          29    8.4       Europe
# 5    Suriname       27.8         4 44.5          11   11.9     Americas
# 6  Mozambique       27.4         8 34.2           2   21.1       Africa
#         Region.UN Population.2016 Population.2015 Pop.Growth.Percent
# 1   South America          770610          767085          0.4595319
# 2    Eastern Asia        50503933        50293439          0.4185317
# 3   Southern Asia        20810816        20715010          0.4624956
# 4 Northern Europe         2850030         2878405         -0.9857890
# 5   South America          547610          542975          0.8536305
# 6  Eastern Africa        28751362        27977863          2.7646822

# %%
ggplot(suicides, aes(Female, Male, label=Country, color=Continent.UN, size=Population.2016)) +
  geom_point() +
  geom_abline(slope=1, intercept=0)
# Out:
# plot without title

# %%
ggplot(suicides, aes(Female, Male, label=Country, color=Continent.UN, size=Population.2016)) +
  geom_text() +
  scale_x_sqrt() +
  scale_y_sqrt()
# Out:
# plot without title

# %%
ggplot(suicides, aes(Female, Male/Female, label=Country, color=Continent.UN, size=Population.2016)) +
  geom_text() +
  scale_x_log10() +
  scale_y_log10()
# Out:
# plot without title

# %%
ggplot(suicides, aes(Both.sexes, Male/Female, label=Country, color=Continent.UN)) +
  geom_text() +
  scale_x_sqrt() +
  scale_y_sqrt()
# Out:
# plot without title

# %%
suicides_some <- suicides %>% filter(Population.2016 > 1e6)
ggplot(suicides_some, aes(Both.sexes, Male/Female, label=Country, color=Continent.UN, size=Population.2016)) +
  geom_text()
# Out:
# plot without title

# %%
library("scales")

# %%
suicides_some <- suicides %>% filter(Population.2016 > 1e6)
ggplot(suicides_some, aes(Both.sexes, Male/Female, label=Country, color=Pop.Growth.Percent, size=Population.2016)) +
  geom_text() +
  scale_color_gradientn(colours = c("blue","black","red"), 
                        values = rescale(c(-1,0,4)),
                         guide = "colorbar", limits=c(-1,4))
# Out:
# plot without title

# %%
suicides_some <- suicides %>% filter(Population.2016 > 1e6)
ggplot(suicides_some, aes(Pop.Growth.Percent, Male/Female, label=Country, color=Continent.UN, size=Population.2016)) +
  geom_text() +
  scale_y_sqrt()
# Out:
# plot without title

# %%
suicides_some <- suicides %>% filter(Population.2016 > 1e6)
ggplot(suicides_some, aes(Both.sexes, Male/Female, label=Country, color=Region.UN, size=Population.2016)) +
  geom_text()
# Out:
# plot without title
